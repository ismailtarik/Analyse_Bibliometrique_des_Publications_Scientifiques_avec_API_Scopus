# %% [markdown]
# <a href="https://colab.research.google.com/github/Tarikismail2/Analyse_Bibliom-trique_des_Publications_Scientifiques_avec_l-API_Scopus/blob/main/eda_scopus_data.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np

# %%
#import Scraped data
scopus_data = pd.read_csv('/content/scopus_publications_multiple_topics_2024-06-17_17-51-44.csv')

# %%
scopus_data.head()
# Out:
#                      Topic                                              Title  \
# 0  artificial intelligence  Perspectives on label-free microscopy of heter...
# 1  artificial intelligence  Autoencoder-based image denoiser suitable for ...
# 2  artificial intelligence  An Artificial Intelligence Approach to Monitor...
# 3  artificial intelligence  Efficient and easily recyclable photocatalytic...
# 4  artificial intelligence  Modified Levey-Jennings Chart with Robust Esti...
#
#        Authors                                        Publication        Date  \
# 0    Pham D.L.                       Journal of biomedical optics  2025-12-01
# 1  Maghraby M.  Journal of Advanced Research in Applied Scienc...  2025-03-01
# 2   Haron N.H.  Journal of Advanced Research in Applied Scienc...  2025-02-01
# 3     Liang Y.             Separation and Purification Technology  2025-01-01
# 4    Dahari S.  Journal of Advanced Research in Applied Scienc...  2025-01-01
#
#    Citations Volume               Issue    Pages  \
# 0          0     29  No issue available   S22702
# 1          0     44                   2  234-246
# 2          0     44                   1  105-119
# 3          0    352  No issue available      NaN
# 4          0     43                   2  189-202
#
#                             DOI               Abstract
# 0    10.1117/1.JBO.29.S2.S22702  No abstract available
# 1   10.37934/araset.44.2.234246  No abstract available
# 2   10.37934/araset.44.1.105119  No abstract available
# 3  10.1016/j.seppur.2024.128021  No abstract available
# 4   10.37934/araset.43.2.189202  No abstract available

# %% [markdown]
# ## Supprimer les doublons par titre et conserver la première occurrence

# %%
scopus_data =scopus_data.drop_duplicates(subset="Title",keep="first")
scopus_data['Date'] = pd.to_datetime(scopus_data['Date'])
scopus_data['Year'] = scopus_data['Date'].dt.year

# %%
scopus_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 473 entries, 0 to 499
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Topic        473 non-null    object
#  1   Title        473 non-null    object
#  2   Authors      473 non-null    object
#  3   Publication  473 non-null    object
#  4   Date         473 non-null    datetime64[ns]
#  5   Citations    473 non-null    int64
#  6   Volume       473 non-null    object
#  7   Issue        473 non-null    object
#  8   Pages        89 non-null     object
#  9   DOI          473 non-null    object
#  10  Abstract     473 non-null    object
#  11  Year         473 non-null    int32
# dtypes: datetime64[ns](1), int32(1), int64(1), object(9)
# memory usage: 46.2+ KB

# %%
scopus_data[['Citations','Year']].describe()
# Out:
#         Citations         Year
# count  473.000000   473.000000
# mean     0.069767  2024.169133
# std      0.358604     0.375266
# min      0.000000  2024.000000
# 25%      0.000000  2024.000000
# 50%      0.000000  2024.000000
# 75%      0.000000  2024.000000
# max      4.000000  2025.000000

# %%
scopus_data.dtypes
# Out:
# Topic                  object
# Title                  object
# Authors                object
# Publication            object
# Date           datetime64[ns]
# Citations               int64
# Volume                 object
# Issue                  object
# Pages                  object
# DOI                    object
# Abstract               object
# Year                    int32
# dtype: object

# %% [markdown]
# ## Convertir la colonne 'Date' en datetime pour faciliter l'analyse

# %%
scopus_data['Date'] = pd.to_datetime(scopus_data['Date'])
scopus_data.dtypes
# Out:
# Topic                  object
# Title                  object
# Authors                object
# Publication            object
# Date           datetime64[ns]
# Citations               int64
# Volume                 object
# Issue                  object
# Pages                  object
# DOI                    object
# Abstract               object
# Year                    int32
# dtype: object

# %% [markdown]
# ##  S'assurer que 'Citations' est de type int pour les opérations de somme

# %%
scopus_data['Citations'] = pd.to_numeric(scopus_data['Citations']).fillna(0).astype(int)
scopus_data.dtypes
# Out:
# Topic                  object
# Title                  object
# Authors                object
# Publication            object
# Date           datetime64[ns]
# Citations               int64
# Volume                 object
# Issue                  object
# Pages                  object
# DOI                    object
# Abstract               object
# Year                    int32
# dtype: object

# %% [markdown]
# ## Calculer le nombre total de citations pour chaque Topic

# %%
total_citation = scopus_data.groupby("Topic")["Citations"].sum().reset_index()
total_citation.rename(columns={"Citations":"Total Cited"},inplace=True)
total_citation.sort_values(by="Total Cited",ascending=False)
# Out:
#                           Topic  Total Cited
# 17             renewable energy            6
# 2           autonomous vehicles            5
# 0       artificial intelligence            4
# 5                 biotechnology            4
# 13             machine learning            4
# 14               nanotechnology            3
# 11                     genomics            3
# 1             augmented reality            1
# 10                 data science            1
# 8               computer vision            1
# 7               cloud computing            1
# 9                 cybersecurity            0
# 12           internet of things            0
# 6                    blockchain            0
# 4                bioinformatics            0
# 15  natural language processing            0
# 16            quantum computing            0
# 3                      big data            0
# 18                     robotics            0
# 19              virtual reality            0

# %% [markdown]
# ##  Analyser la répartition des publications par année

# %%
publications_per_year = scopus_data.groupby("Year")["Title"].count().reset_index(name="Publication")
publications_per_year
# Out:
#    Year  Publication
# 0  2024          393
# 1  2025           80

# %% [markdown]
# ## Calculer des statistiques telles que la moyenne, la médiane, le minimum et le maximum des citations pour comprendre l'impact des citations des publications.

# %%
citation_statistics = { 'Mean Citations': scopus_data['Citations'].mean(),
    'Median Citations': scopus_data['Citations'].median(),
    'Min Citations': scopus_data['Citations'].min(),
    'Max Citations': scopus_data['Citations'].max() }

print("Statistiques de citations :")
for stat, value in citation_statistics.items():
     print(f"{stat} : {value:.2f}")
# Out:
# Statistiques de citations :
# Mean Citations : 0.07
# Median Citations : 0.00
# Min Citations : 0.00
# Max Citations : 4.00

# %% [markdown]
# ## Identifier les publications avec les citations les plus élevées.

# %%
top_publications = scopus_data.sort_values(by="Citations",ascending=False).head(5)
top_publications
# Out:
#                        Topic  \
# 352         renewable energy
# 38          machine learning
# 402            biotechnology
# 378           nanotechnology
# 10   artificial intelligence
#
#                                                  Title     Authors  \
# 352  Unveiling the photocatalytic marvels: Recent a...   Askari N.
# 38   Spatial differentiation of carbon emissions fr...      Cao H.
# 402  Hybrid and enhanced electrokinetic system for ...  Hamdi F.M.
# 378  Highly efficient catalytic transfer hydrogenat...       Lu A.
# 10   Diabetes and its associated factors: A Retrosp...     Amin F.
#
#                                    Publication       Date  Citations Volume  \
# 352  Journal of Environmental Sciences (China) 2025-02-01          4    148
# 38   Journal of Environmental Sciences (China) 2025-03-01          3    149
# 402  Journal of Environmental Sciences (China) 2025-01-01          3    147
# 378  Journal of Environmental Sciences (China) 2025-02-01          2    148
# 10        Pakistan Journal of Medical Sciences 2024-12-05          2     40
#
#                   Issue    Pages                            DOI  \
# 352  No issue available  283-297      10.1016/j.jes.2024.01.006
# 38   No issue available  358-373      10.1016/j.jes.2023.08.007
# 402  No issue available  424-450      10.1016/j.jes.2023.11.005
# 378  No issue available  515-528      10.1016/j.jes.2023.10.010
# 10                    2  S10-S14  10.12669/pjms.40.2(ICON).8948
#
#                   Abstract  Year
# 352  No abstract available  2025
# 38   No abstract available  2025
# 402  No abstract available  2025
# 378  No abstract available  2025
# 10   No abstract available  2024

# %% [markdown]
# ## Analyser la répartition des publications par auteurs. Cela peut aider à comprendre les modèles de collaboration.

# %%
publications_per_author = scopus_data.groupby('Authors').size().reset_index(name='Publications')
publications_per_author.sort_values(by="Publications",ascending=False).head(10)
# Out:
#          Authors  Publications
# 388      Wang Y.             5
# 228        Li Y.             3
# 225        Li L.             3
# 424     Zhang J.             3
# 430     Zhang Y.             3
# 213  Laskar M.R.             2
# 125       Gao Y.             2
# 153       Han S.             2
# 385      Wang R.             2
# 175     Huang S.             2

# %% [markdown]
# ##  Auteur avec le plus de publications

# %%
author_counts = scopus_data['Authors'].value_counts()
(author_counts[author_counts == author_counts.max()]).reset_index(name='Publications')
# Out:
#    Authors  Publications
# 0  Wang Y.             5

# %% [markdown]
# ## Revue (Publication) avec le plus  d'articles publiés

# %%
journal_counts = scopus_data['Publication'].value_counts()
(journal_counts[journal_counts == journal_counts.max()]).reset_index(name="Articles")
# journal_counts.head(5).reset_index(name="Articles")
# Out:
#           Publication  Articles
# 0  Scientific Reports        80

# %% [markdown]
# ## Afficher les 5 revues avec le plus d'articles publiéss

# %%
journal_counts_5 = scopus_data["Publication"].value_counts()
journal_counts.head(5).reset_index(name="Articles")
# Out:
#                                          Publication  Articles
# 0                                 Scientific Reports        80
# 1  Journal of Advanced Research in Applied Scienc...        30
# 2                              Nature Communications        27
# 3          Journal of Environmental Sciences (China)        20
# 4                         Journal of Cloud Computing        15

# %% [markdown]
# ## Examiner la répartition des publications à travers différents sujets pour voir quels domaines sont les plus étudiés

# %%
publications_per_topic = scopus_data.groupby("Topic").size().reset_index(name='Publications')
publications_per_topic
# Out:
#                           Topic  Publications
# 0       artificial intelligence            25
# 1             augmented reality            25
# 2           autonomous vehicles            25
# 3                      big data            23
# 4                bioinformatics            25
# 5                 biotechnology            24
# 6                    blockchain            23
# 7               cloud computing            25
# 8               computer vision            23
# 9                 cybersecurity            21
# 10                 data science            23
# 11                     genomics            23
# 12           internet of things            19
# 13             machine learning            24
# 14               nanotechnology            25
# 15  natural language processing            25
# 16            quantum computing            25
# 17             renewable energy            25
# 18                     robotics            23
# 19              virtual reality            22

# %% [markdown]
# ## Analyser comment les publications dans chaque sujet ont évolué au fil des années.

# %%
publications_per_topic_year = scopus_data.groupby(['Topic', 'Year']).size().reset_index(name='Publications')
publications_per_topic_year
# Out:
#                           Topic  Year  Publications
# 0       artificial intelligence  2024            18
# 1       artificial intelligence  2025             7
# 2             augmented reality  2024            25
# 3           autonomous vehicles  2024            25
# 4                      big data  2024            19
# 5                      big data  2025             4
# 6                bioinformatics  2024            24
# 7                bioinformatics  2025             1
# 8                 biotechnology  2024            20
# 9                 biotechnology  2025             4
# 10                   blockchain  2024            20
# 11                   blockchain  2025             3
# 12              cloud computing  2024            24
# 13              cloud computing  2025             1
# 14              computer vision  2024            19
# 15              computer vision  2025             4
# 16                cybersecurity  2024            18
# 17                cybersecurity  2025             3
# 18                 data science  2024            22
# 19                 data science  2025             1
# 20                     genomics  2024            19
# 21                     genomics  2025             4
# 22           internet of things  2024            10
# 23           internet of things  2025             9
# 24             machine learning  2025            24
# 25               nanotechnology  2024            19
# 26               nanotechnology  2025             6
# 27  natural language processing  2024            22
# 28  natural language processing  2025             3
# 29            quantum computing  2024            25
# 30             renewable energy  2024            19
# 31             renewable energy  2025             6
# 32                     robotics  2024            23
# 33              virtual reality  2024            22

# %% [markdown]
# ## Publications sans résumé (no_abstract)

# %%
no_abstract = scopus_data[scopus_data["Abstract"] == "No abstract available"]
print(len(no_abstract))
# Out:
# 473

# %% [markdown]
# ##Visualisation

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import networkx as nx
import itertools
from wordcloud import WordCloud
from sklearn.feature_extraction.text import CountVectorizer
from collections import defaultdict
sns.set(style="whitegrid")

# %% [markdown]
# ##1-Nombre de publications par sujet

# %%
# Set the style for the plots
sns.set(style="whitegrid")

# Count the number of publications per topic
topic_counts = scopus_data['Topic'].value_counts()

# Create the bar plot
plt.figure(figsize=(12, 6))
sns.barplot(x=topic_counts.index, y=topic_counts.values, palette="viridis")
plt.title('Nombre de publications par sujet')
plt.xlabel('Topic')
plt.ylabel('Nombre de Publications')
plt.xticks(rotation=45)
plt.show()
# Out:
# <ipython-input-31-15a365fab1f7>:9: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=topic_counts.index, y=topic_counts.values, palette="viridis")

# %% [markdown]
# ##2-Variation des publications au cours du temps

# %%
# Convert the Date column to datetime format and extract the year
scopus_data['Date'] = pd.to_datetime(scopus_data['Date'])
scopus_data['Year'] = scopus_data['Date'].dt.year

# Count the number of publications per year
yearly_publications = scopus_data['Year'].value_counts().sort_index()

# Create the line plot
plt.figure(figsize=(12, 6))
sns.lineplot(x=yearly_publications.index, y=yearly_publications.values, marker='o')
plt.title('Variation des publications au cours du temps')
plt.xlabel('Year')
plt.ylabel('Nombre de Publications')
plt.show()

# %% [markdown]
# ##3-Principaux auteurs par nombre de publications

# %%
# Count the number of publications per author
author_counts = scopus_data['Authors'].value_counts().head(10)  # Top 10 authors

# Create the bar plot
plt.figure(figsize=(12, 6))
sns.barplot(x=author_counts.values, y=author_counts.index, palette="viridis")
plt.title('Principaux auteurs par nombre de publications')
plt.xlabel('Nombre de Publications')
plt.ylabel('Authors')
plt.show()
# Out:
# <ipython-input-42-8c2087ae5704>:6: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=author_counts.values, y=author_counts.index, palette="viridis")

# %% [markdown]
# ##4-Distribution des Citations

# %%
# Create the histogram
plt.figure(figsize=(12, 6))
sns.histplot(scopus_data['Citations'], bins=30, kde=True)
plt.title('Distribution des Citations')
plt.xlabel('Nombre de  Citations')
plt.ylabel('Frequency')
plt.show()

# Create the box plot
plt.figure(figsize=(12, 6))
sns.boxplot(x=scopus_data['Citations'])
plt.title('Distribution des Citations')
plt.xlabel('Nombre de  Citations')
plt.show()

# %% [markdown]
# ##5-Publications par journal

# %%
# Count the number of publications per journal
journal_counts = scopus_data['Publication'].value_counts().head(10)  # Top 10 journals

# Create the bar plot
plt.figure(figsize=(12, 6))
sns.barplot(x=journal_counts.values, y=journal_counts.index, palette="viridis")
plt.title('Top 10 des journal par nombre de publications')
plt.xlabel('Nombre de Publications')
plt.ylabel('Journal')
plt.show()
# Out:
# <ipython-input-45-34edcccdc0fb>:6: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=journal_counts.values, y=journal_counts.index, palette="viridis")

# %% [markdown]
# ##6-Publications par année et par sujet

# %%
# Create a pivot table with year and topic
year_topic_pivot = scopus_data.pivot_table(index='Year', columns='Topic', aggfunc='size', fill_value=0)

# Create the line plot
plt.figure(figsize=(12, 8))
year_topic_pivot.plot(kind='line', marker='o')
plt.title('Publications par year et par Topic')
plt.xlabel('Year')
plt.ylabel('Nombre de Publications')
plt.legend(title='Topic')
plt.show()

# %% [markdown]
# ##7-Top 10 Articles par Citations

# %%
# Sort the dataset by number of citations in descending order and select the top 10 articles
top_cited_articles = scopus_data.sort_values(by='Citations', ascending=False).head(10)

# Create the bar plot
plt.figure(figsize=(12, 6))
sns.barplot(x=top_cited_articles['Citations'], y=top_cited_articles['Title'], palette="viridis")
plt.title('Top 10 des articles par nombre de citations')
plt.xlabel('Nombre de Citations')
plt.ylabel('Article Title')
plt.show()
# Out:
# <ipython-input-47-bb90261a1c5b>:6: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=top_cited_articles['Citations'], y=top_cited_articles['Title'], palette="viridis")

# %% [markdown]
# ##8-Nuage de mots de titres d'articles

# %%
# Combine all titles into a single string
all_titles = ' '.join(scopus_data['Title'].dropna().tolist())

# Generate the word cloud
wordcloud = WordCloud(width=800, height=400, background_color='white', colormap='viridis').generate(all_titles)

# Plot the word cloud
plt.figure(figsize=(12, 6))
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis('off')
plt.title('Nuage de mots de titres articles')
plt.show()

# %% [markdown]
# ##9-Carte thermique de corrélation des caractéristiques numériques

# %%
scopus_data['Volume'] = pd.to_numeric(scopus_data['Volume'], errors='coerce')

scopus_data.dropna(subset=['Volume'], inplace=True)

corr = scopus_data[['Citations', 'Volume']].corr()

plt.figure(figsize=(8, 6))
sns.heatmap(corr, annot=True, cmap='viridis')
plt.title('Correlation Heatmap')
plt.show()

# %% [markdown]
# ##10-Distribution des Publications par Mois

# %%
# Extract the month from the Date column
scopus_data['Month'] = scopus_data['Date'].dt.month

# Count the number of publications par month
monthly_publications = scopus_data['Month'].value_counts().sort_index()

# Create the bar plot
plt.figure(figsize=(12, 6))
sns.barplot(x=monthly_publications.index, y=monthly_publications.values, palette="viridis")
plt.title('Distribution des Publications par Mois')
plt.xlabel('Mois')
plt.ylabel('Nombre de Publications')
plt.show()
# Out:
# <ipython-input-51-5a20c8455551>:9: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=monthly_publications.index, y=monthly_publications.values, palette="viridis")

# %% [markdown]
# ##11-Moyenne des Citations par Année

# %%
# Calculate the average number of citations per year
avg_citations_per_year = scopus_data.groupby('Year')['Citations'].mean()

# Create the line plot
plt.figure(figsize=(12, 6))
sns.lineplot(x=avg_citations_per_year.index, y=avg_citations_per_year.values, marker='o')
plt.title('Moyenne des Citations par Année')
plt.xlabel('Année')
plt.ylabel('Moyenne de Citations')
plt.show()
