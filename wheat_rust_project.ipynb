# %% [markdown]
# <a href="https://colab.research.google.com/github/ismailtarik/Analyse_Bibliometrique_des_Publications_Scientifiques_avec_API_Scopus/blob/main/wheat_rust_project.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import os

folders = [
    "wheat_rust_project/data/raw",
    "wheat_rust_project/data/processed",
    "wheat_rust_project/data/annotations",
    "wheat_rust_project/pipelines",
    "wheat_rust_project/models",
    "wheat_rust_project/outputs",
    "wheat_rust_project/configs"
]

for folder in folders:
    os.makedirs(folder, exist_ok=True)

print("Project structure created successfully!")
# Out:
# Project structure created successfully!

# %%
import kagglehub
path = kagglehub.dataset_download("emmarex/plantdisease")
# Out:
# Using Colab cache for faster access to the 'plantdisease' dataset.
