# %% [markdown]
# <a href="https://colab.research.google.com/github/ismailtarik/Analyse_Bibliometrique_des_Publications_Scientifiques_avec_API_Scopus/blob/main/TP1_ML_DL.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install numpy pandas matplotlib scikit-learn

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error, r2_score

# %%
data = pd.read_csv('/content/TP1_dataset.csv', sep=';');

# %%
data.head()
# Out:
#    Taille  Poids
# 0     100     36
# 1     110     38
# 2     120     43
# 3     130     45
# 4     140     48

# %%
print(data.columns)
# Out:
# Index(['Taille', 'Poids'], dtype='object')

# %%
data.columns = data.columns.str.strip()  # Supprime les espaces

# %%
X = data[['Taille']]
Y = data['Poids']

# %%
data.isnull().sum()
# Out:
# Taille    0
# Poids     0
# dtype: int64

# %%
data = data.dropna()

# %%
plt.scatter(X, Y, color='blue')
plt.xlabel('Taille')
plt.ylabel('Poids')
plt.title('Taille vs Poids')
plt
# Out:
# <module 'matplotlib.pyplot' from '/usr/local/lib/python3.10/dist-packages/matplotlib/pyplot.py'>

# %%
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.2, random_state=42)

# %%
model = LinearRegression()
model.fit(X_train, Y_train)
# Out:
# LinearRegression()

# %%
Y_pred=model.predict(X_test)

# %%
rmse = np.sqrt(mean_squared_error(Y_test, Y_pred))
r2 = r2_score(Y_test, Y_pred)
print("RMSE:", rmse)
print("R2:", r2)
# Out:
# RMSE: 5.785264212369252
# R2: 0.91729172485934

# %%
plt.scatter(X, Y, color='blue')
plt.plot(X, model.predict(X), color='red', linewidth=2)
plt.xlabel('Taille')
plt.ylabel('Poids')
plt.title('Taille vs Poids')
plt.show()

# %%
print("Pente:",model.coef_[0])
print("Ordonnée à l'origine:",model.intercept_)
# Out:
# Pente: 0.4794117647058822
# Ordonnée à l'origine: -18.108823529411737

# %%
# La pente indique l'influence de la taille sur le poids.
# L'ordonnée à l'origine indique le poids prédit lorsque la taille est égale à zéro.
